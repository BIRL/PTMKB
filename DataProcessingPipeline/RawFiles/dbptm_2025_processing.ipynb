# %%
import numpy as np
import pandas as pd
from glob import glob

# %%
def get_files():
    files = [''.join(i.split('.')[:-1]).replace('\\', '/') for i in glob('rawDataset2025/*.zip')]
    files = dict.fromkeys([i.split('/')[-1] for i in files])
    return files

files = get_files()

ptms = list(files.keys())
for ptm in ptms:
    files[ptm] = ptm

# %%
def construct_subsequence(protein: str, site: int, no_stream_aa: int = 10):
    # Treat PTM site as 0-based (so subtract 1 for convenience)
    start = max(0, site - no_stream_aa)
    end = min(len(protein), site + no_stream_aa + 1)

    subsequence: str = protein[start:end]

    if site < no_stream_aa:
        subsequence = ('-' * (no_stream_aa - site)) + subsequence 
    if site + no_stream_aa > len(protein):
        subsequence += ('-' * ((site + no_stream_aa + 1) - len(protein)))
    
    return subsequence

# %%
import requests

def fetch_prot_id(accession_number: str) -> str:
    got_response = True
    got_id = True
    while got_response:
        try:
            got_response = False
            response = requests.get(
                f'http://www.ebi.ac.uk/proteins/api/proteins/{accession_number}'
            )
            print(f"\tGot response for {accession_number}.")
        except:
            got_response = True
        try:
            _id = response.json()['id']
        except:
            got_response = True
            while got_response:
                try:
                    got_response = False
                    response = requests.get(
                        f'https://rest.uniprot.org/uniprotkb/{accession_number}',
                        headers={
                            'Accept': 'application/json'
                        }
                    )
                    print("\tGot response for", accession_number)
                except Exception as e:
                    got_response = True
            got_id = True
            try:
                response: dict = response.json()
                _id = response['uniProtkbId']
            except Exception as e:
                _id = ''
                got_id = False
                print("\t\tNo sequence found for", accession_number)

    return (got_id, _id)


def fetch_sequence(accession_number: str) -> tuple[bool, str]:
    got_response = True
    got_sequence = True
    while got_response:
        try:
            got_response = False
            response = requests.get(
                f'http://www.ebi.ac.uk/proteins/api/proteins/{accession_number}'
            )
            print(f"\tGot response for {accession_number}.")
        except:
            got_response = True
        try:
            sequence = response.json()['sequence']['sequence']
        except:
            got_response = True
            while got_response:
                try:
                    got_response = False
                    response = requests.get(
                        f'https://rest.uniprot.org/uniprotkb/{accession_number}',
                        headers={
                            'Accept': 'application/json'
                        }
                    )
                    print("\tGot response for", accession_number)
                except Exception as e:
                    got_response = True
            got_sequence = True
            try:
                response: dict = response.json()
                if 'inactiveReason' in response.keys():
                    if response['inactiveReason']['inactiveReasonType'] == 'DELETED':
                        print("\tWas deleted")
                        uniparc_id = response['extraAttributes']['uniParcId']
                        got_response = True
                        while got_response:
                            try:
                                got_response = False
                                response: dict = requests.get(
                                    f'https://rest.uniprot.org/uniparc/{uniparc_id}',
                                    headers={
                                        'Accept': 'application/json'
                                    }
                                )
                            except Exception as e:
                                got_response = True
                    elif response['inactiveReason']['inactiveReasonType'] == 'DEMERGED':    
                        print("\tWas merged")
                        accession_number = response['inactiveReason']['mergeDemergeTo'][0]
                        got_response = True
                        while got_response:
                            try:
                                got_response = False
                                response: dict = requests.get(
                                    f'https://rest.uniprot.org/uniprotkb/{accession_number}',
                                    headers={
                                        'Accept': 'application/json'
                                    }
                                )
                            except Exception as e:
                                got_response = True
                    sequence = response.json()['sequence']['value']
                else:
                    sequence = response['sequence']['value']
            except Exception as e:
                sequence = ''
                got_sequence = False
                print("\t\tNo sequence found for", accession_number)

    return (got_sequence, sequence)



# positions = invalid_sequence_df[invalid_sequence_df['Acc#'] == accession_number].ModSite.to_list()
# for position in positions:
#     if got_sequence:
#         subsequence = construct_subsequence(sequence, position-1)
#     else:
#         subsequence = ''
#     df.loc[(df['Acc#'] == accession_number) & (df['ModSite'] == position), 'Seq'] = subsequence

# %%
def fill_sequences_of_ptm(ptm: str) -> None:
    df = pd.read_csv(
        'rawDataset2025/' + ptm,
        names=[
            'ProID',
            'Acc#',
            'ModSite',
            'PTM',
            'EvdId',
            'Seq'
        ],
        header=None,
        sep='\t'
    )
    nan_df = df[df['Seq'].isna()]
    if len(nan_df):
        print("NAN FOR", ptm, "FOUND - TOTAL", len(nan_df))
        for acc in nan_df['Acc#'].unique():
            got_sequence, sequence = fetch_sequence(acc)
            for position in nan_df[nan_df['Acc#'] == acc].ModSite.to_list():
                if got_sequence:
                    subsequence = construct_subsequence(sequence, position-1)
                else:
                    subsequence = ''
                df.loc[(df['Acc#'] == acc) & (df['ModSite'] == position), 'Seq'] = subsequence
    else:
        print("No NAN for", ptm)
    df.to_csv(f'rawDataset2025/{ptm}.csv', index=False)

# %%
from threading import Thread

class CustomThread(Thread):
    def __init__(self, group=None, target=None, name=None, args=(), kwargs={}, verbose=None):
        # Initializing the Thread class
        super().__init__(group, target, name, args, kwargs)
        self._return = None

    # Overriding the Thread.run function
    def run(self):
        if self._target is not None:
            self._return = self._target(*self._args, **self._kwargs)

    def join(self):
        super().join()
        return self._return

# %%
import aiohttp
import asyncio

# Set a maximum number of concurrent requests
MAX_CONCURRENT_REQUESTS = 50  # Change this number as needed

# Semaphore to limit concurrent HTTP requests
semaphore = asyncio.Semaphore(MAX_CONCURRENT_REQUESTS)

async def fetch_sequence_thread(accession_number: str) -> tuple[str, bool, str]:
    real_acc = accession_number
    got_response = True
    got_sequence = True
    sequence = ''
    
    async with semaphore:
        async with aiohttp.ClientSession() as session:
            while got_response:
                try:
                    got_response = False
                    async with session.get(f'http://www.ebi.ac.uk/proteins/api/proteins/{accession_number}') as response:
                        print(f"\tGot response for {accession_number}.")
                        if response.status == 200:
                            data = await response.json()
                            sequence = data['sequence']['sequence']
                            got_sequence = True
                        else:
                            got_sequence = False
                            print(f"\tError: {response.status} while fetching from EBI API")
                except Exception as e:
                    print(f"\tError fetching from EBI API: {e}")
                    got_response = True

            if not got_sequence:  # If sequence wasn't found in the first API, try the second one
                while got_response:
                    try:
                        got_response = False
                        async with session.get(f'https://rest.uniprot.org/uniprotkb/{accession_number}', headers={'Accept': 'application/json'}) as response:
                            print(f"\tGot response for {accession_number} from UniProt.")
                            if response.status == 200:
                                data = await response.json()
                                if 'inactiveReason' in data:
                                    if data['inactiveReason']['inactiveReasonType'] == 'DELETED':
                                        print("\tWas deleted")
                                        uniparc_id = data['extraAttributes']['uniParcId']
                                        # Try fetching UniParc data
                                        async with session.get(f'https://rest.uniprot.org/uniparc/{uniparc_id}', headers={'Accept': 'application/json'}) as uniparc_response:
                                            if uniparc_response.status == 200:
                                                uniparc_data = await uniparc_response.json()
                                                sequence = uniparc_data['sequence']['value']
                                                got_sequence = True
                                    elif data['inactiveReason']['inactiveReasonType'] == 'DEMERGED':
                                        print("\tWas merged")
                                        accession_number = data['inactiveReason']['mergeDemergeTo'][0]
                                        got_response = True
                                        continue  # If merged, retry with new accession number
                                else:
                                    sequence = data['sequence']['value']
                                    got_sequence = True
                            else:
                                print(f"\tError: {response.status} while fetching from UniProt")
                    except Exception as e:
                        print(f"\tError fetching from UniProt API: {e}")
                        got_response = True

    return real_acc, got_sequence, sequence

# %%
# thread = CustomThread(target=fetch_sequence, args=())
# thread.start()
# print(thread.join())  # This is where you get your return value.p

async def main(file):
    print("DOING FOR", file)
    df = pd.read_csv(
    'rawDataset2025/' + file,
        names=[
            'ProID',
            'Acc#',
            'ModSite',
            'PTM',
            'EvdId',
            'Seq'
        ],
        header=None,
        sep='\t'
    )
    df['FullSeq'] = ''
    responses = [fetch_sequence_thread(acc) for acc in df['Acc#'].unique()]
    results = await asyncio.gather(*responses)
    for result in results:
        df.loc[df['Acc#'] == result[0], 'FullSeq'] = result[2]
    df.to_csv('rawDataset2025/' + file + '_full.csv', index=False)
    print("DONE FOR", file)

# %%
it = iter(get_files())

# %%
await main(next(it))
# Out:
# DOING FOR Acetylation
# 	Got response for P18281.
# 	Got response for O23629.
# 	Got response for P19456.
# 	Got response for P46077.
# 	Got response for Q9XIE2.
# 	Got response for Q9SLG0.
# 	Got response for Q9T074.
# 	Got response for Q9LQQ4.
# 	Got response for O81270.
# 	Got response for Q9ZVI3.
# 	Got response for Q06611.
# 	Got response for Q9SJT1.
# 	Got response for Q9SZR1.
# 	Got response for Q56YA5.
# 	Got response for Q6NLC1.
# 	Got response for Q39196.
# 	Got response for Q08733.
# 	Got response for Q56Z59.
# 	Got response for Q56ZI2.
# 	Got response for P59169.
# 	Got response for Q9XII1.
# 	Got response for Q8VZ95.
# 	Got response for Q9LF97.
# 	Got response for P54150.
# 	Got response for P06525.
# 	Got response for Q9ZSD4.
# 	Got response for Q1WIQ6.
# 	Got response for Q9CAI7.
# 	Got response for O81108.
# 	Got response for Q9FVE6.
# 	Got response for P56780.
# 	Got response for Q9C5Z1.
# 	Got response for P42643.
# 	Got response for Q9SKZ1.
# 	Got response for Q08682.
# 	Got response for Q9SVC2.
# 	Got response for P83755.
# 	Got response for P56778.
# 	Got response for Q9SFD5.
# 	Got response for O03042.
# 	Got response for Q8LCE1.
# 	Got response for Q8RWY6.
# 	Got response for Q9SJI7.
# 	Got response for Q9FIQ0.
# 	Got response for Q6AWX0.
# 	Got response for P04778.
# 	Got response for Q93W28.
# 	Got response for P54609.
# 	Got response for Q39002.
# 	Got response for Q56WK6.
# 	Got response for O23712.
# 	Got response for Q56WH4.
# 	Got response for Q9LZT0.
# 	Got response for Q9LS42.

# 	Error fetching from EBI API: Cannot connect to host www.ebi.ac.uk:443 ssl:default [Connect call failed ('193.62.193.80', 443)]
# 	Error fetching from EBI API: Cannot connect to host www.ebi.ac.uk:443 ssl:default [Connect call failed ('193.62.193.80', 443)]
# 	Got response for Q9NIU5.
# 	Got response for Q9VEA2.
# 	Got response for A1Z9E2.
# 	Got response for Q9V726.
# 	Got response for Q24109.
# 	Got response for Q8SYU2.
# 	Got response for Q9VMW7.
# 	Got response for P11147.
# 	Got response for Q86BQ4.
# 	Got response for Q95SY9.
# 	Got response for Q95RB1.
# 	Got response for Q0KI68.
# 	Got response for Q961R8.
# 	Error: 404 while fetching from EBI API
# 	Got response for Q8IGN0.
# 	Got response for A1Z7U8.
# 	Got response for P84051.
# 	Got response for Q9NKV0.
# 	Got response for Q24407.
# 	Got response for P48604.
# 	Got response for Q8SYG6.
# 	Got response for A1Z7H3.
# 	Got response for Q9VI14.
# 	Got response for Q5U108.
# 	Got response for Q27268.
# 	Got response for Q8SZ48.
# 	Got response for P48605.
# 	Got response for O18413.
# 	Got response for P20432.
# 	Error fetching from EBI API: Cannot connect to host www.ebi.ac.uk:443 ssl:default [Connect call failed ('193.62.193.80', 443)]
# 	Got response for Q8WQ62.
# 	Got response for A1Z909.
# 	Got response for P13060.
# 	Got response for Q5U156.
# 	Got response for Q7KUB0.
# 	Got response for Q9W3B2.
# 	Got response for Q9W1J3.
# 	Got response for P49630.
# 	Got response for Q7K0F7.
# 	Got response for P29844.
# 	Got response for A1ZBJ2.
# 	Got response for Q9VM75.
# 	Got response for Q24439.
# 	Got response for Q7K5M2.
# 	Got response for Q8SWX1.
# 	Got response for Q9VHQ5.
# 	Got response for Q9W3Y0.
# 	Got response for Q9VDN4.
# 	Got response for Q95R41.
# 	Got response for Q95R45.
# 	Error fetching from EBI API: Cannot connect to host www.ebi.ac.uk:80 ssl:default [Connect call failed ('193.62.193.80', 80)]
# 	Got response for Q8T8Y7.
# 	Got response for P20477.
# 	Got response for P22817.
# 	Got response for Q9VBN5.
# 	Got response for Q8IGC1.
# 	Got response for Q6B4I4.
# 	Got response for Q9VRT7.
# 	Error fetching from EBI API: Cannot connect to host www.ebi.ac.uk:80 ssl:default [Connect call failed ('193.62.193.80', 80)]
# 	Got response for O02193.
# 	Got response for Q9VS52.
# 	Got response for P50535.
# 	Got response for P18101.
# 	Error fetching from EBI API: Cannot connect to host www.ebi.ac.uk:443 ssl:default [Connect call failed ('193.62.193.80', 443)]
# 	Got response for P54385.
# 	Got response for O77134.
# 	Got response for Q8SYN6.
# 	Got response for Q8MT18.
# 	Got response for Q8IRD3.
# 	Got response for Q5U1D1.
# 	Got response for Q8IGT5.
# 	Got response for Q9VQK7.
# 	Got response for Q7K8X7.
# 	Got response for Q9VXJ0.
# 	Got response for Q8IGT0.
# 	Got response for Q86NT0.
# 	Got response for Q0E940.
# 	Got response for O18640.
# 	Got response for Q5U117.
# 	Got response for O02393.
# 	Got response for Q9VHC8.
# 	Got response for P52654.
# 	Got response for Q9VPS5.
# 	Got response for Q8IH48.
# 	Got response for Q7KMQ0.
# 	Got response for Q9VAF4.
# 	Got response for Q9VNG2.
# 	Got response for Q9VZI1.
# 	Got response for Q0E8E8.
# 	Got response for Q9VTB4.
# 	Got response for Q7JVH0.
# 	Got response for Q9VWA8.
# 	Got response for Q9VRN3.
# 	Got response for Q2EZ47.
# 	Error: 404 while fetching from EBI API
# 	Got response for Q86P00.
# 	Got response for Q24159.
# 	Got response for Q9VI16.
# 	Got response for P54622.
# 	Got response for P18053.
# 	Got response for Q8MT59.
# 	Got response for Q9VDI1.
# 	Got response for Q9W0Y2.
# 	Got response for Q9V6U9.
# 	Got response for Q6IDF5.
# 	Got response for Q9VCZ8.
# 	Got response for Q9VUU7.
# 	Got response for Q9VI56.
# 	Got response for Q9VSK9.
# 	Got response for P91944.
# 	Got response for Q9W1A8.
# 	Got response for Q9W5N2.
# 	Got response for Q9VCC6.
# 	Got response for Q9VVA6.
# 	Got response for P48588.
# 	Got response for Q8IQF8.
# 	Got response for Q9VWH4.
# 	Got response for Q0KI58.
# 	Got response for Q9VB23.
# 	Got response for Q9VP04.
# 	Got response for Q9VAA9.
# 	Got response for Q9V3W7.
# 	Got response for Q95TF1.
# 	Got response for Q2XYH0.
# 	Got response for Q9VD51.
# 	Got response for P47825.
# 	Got response for Q8SXD0.
# 	Got response for P91891.
# 	Got response for Q7K2E1.
# 	Got response for Q7JXC4.
# 	Got response for Q9VM36.
# 	Got response for O77460.
# 	Got response for Q7YTZ9.
# 	Got response for P32392.
# 	Error fetching from EBI API: Cannot connect to host www.ebi.ac.uk:80 ssl:default [Connect call failed ('193.62.193.80', 80)]
# 	Got response for Q8T3K9.
# 	Got response for A1Z9S5.
# 	Got response for Q9W1X4.
# 	Got response for Q8IP37.
# 	Error: 404 while fetching from EBI API
# 	Got response for Q8I0M2.
# 	Got response for Q9VFB2.
# 	Got response for O77466.
# 	Got response for P46222.
# 	Got response for Q8SYC8.
# 	Got response for Q7KML1.
# 	Got response for Q03334.
# 	Got response for Q86NP2.
# 	Got response for Q9VHL2.
# 	Got response for Q24150.
# 	Got response for Q9VC53.
# 	Got response for Q8MLY8.
# 	Got response for Q26365.
# 	Got response for O97118.
# 	Got response for Q9VG78.
# 	Got response for Q8SXM8.
# 	Got response for P46150.
# 	Got response for Q8MSG1.
# 	Got response for Q9V436.
# 	Got response for P38979.
# 	Got response for Q8IGI6.
# 	Got response for Q7JXU4.
# 	Got response for Q9W397.
# 	Got response for Q9Y105.
# 	Got response for Q8IHH1.
# 	Got response for Q8SYQ8.
# 	Got response for Q9VIP0.
# 	Got response for O62619.
# 	Error fetching from EBI API: Cannot connect to host www.ebi.ac.uk:80 ssl:default [Connect call failed ('193.62.193.80', 80)]
# 	Got response for Q8T3L6.
# 	Got response for O02373.
# 	Got response for Q8MRT0.
# 	Got response for A1Z830.
# 	Error fetching from EBI API: Cannot connect to host www.ebi.ac.uk:80 ssl:default [Connect call failed ('193.62.193.80', 80)]
# 	Got response for P17704.
# 	Got response for P32100.
# 	Got response for Q9W141.
# 	Got response for Q7KUQ2.
# 	Got response for Q9VTU4.
# 	Got response for Q9W5W8.
# 	Got response for Q7KNM2.
# 	Got response for Q9VMH2.
# 	Error fetching from EBI API: Cannot connect to host www.ebi.ac.uk:443 ssl:default [Connect call failed ('193.62.193.80', 443)]
# 	Got response for Q8SWV8.
# 	Got response for O77263.
# 	Got response for Q9VBX4.
# 	Got response for O46111.
# 	Got response for Q9VRJ9.
# 	Got response for Q9VRJ4.
# 	Got response for Q8SYT1.
# 	Got response for Q9VLU0.
# 	Error fetching from EBI API: Cannot connect to host www.ebi.ac.uk:443 ssl:default [Connect call failed ('193.62.193.80', 443)]
# 	Got response for Q9TVQ5.
# 	Got response for Q7K3J0.
# 	Got response for Q9VNE9.
# 	Got response for Q9U3V9.
# 	Error fetching from EBI API: Cannot connect to host www.ebi.ac.uk:80 ssl:default [Connect call failed ('193.62.193.80', 80)]
# 	Got response for Q8IH15.
# 	Got response for Q8IPE8.
# 	Got response for Q8INP8.
# 	Got response for P09180.
# 	Got response for Q9VNV3.
# 	Got response for Q95S48.
# 	Got response for Q9VC94.
# 	Got response for P54367.
# 	Got response for Q9VHR8.
# 	Got response for Q9XYF4.
# 	Got response for Q9VH64.
# 	Got response for Q9VGL0.
# 	Got response for Q9VPB0.
# 	Got response for Q04499.
# 	Got response for Q9W227.
# 	Got response for Q9NJH0.
# 	Got response for Q9V668.
# 	Got response for A1Z6M6.
# 	Got response for Q9W3C8.
# 	Got response for Q94514.
# 	Got response for Q9VZU0.
# 	Got response for Q7KND8.
# 	Got response for Q8SX89.
# 	Got response for Q9VDV2.
# 	Got response for Q8IR24.
# 	Error: 404 while fetching from EBI API
# 	Got response for O44435.
# 	Got response for Q9U9Q4.
# 	Got response for Q8MRM6.
# 	Got response for Q95SH2.
# 	Got response for P52486.
# 	Got response for Q9VMH8.
# 	Got response for Q8MSB1.
# 	Got response for P54399.
# 	Got response for Q86BP6.
# 	Got response for Q9VSA3.
# 	Got response for Q7KW39.
# 	Got response for Q9Y145.
# 	Got response for Q9NJH7.
# 	Got response for Q8IGE9.
# 	Got response for Q8IQ71.
# 	Got response for Q9VC06.
# 	Got response for Q5BIE3.
# 	Got response for O61540.
# 	Got response for Q8SZU2.
# 	Got response for Q9V431.
# 	Got response for Q9W048.
# 	Got response for Q9VQ77.
# 	Got response for Q27272.
# 	Got response for Q9VLT7.
# 	Got response for Q7JWP6.
# 	Got response for O96542.
# 	Got response for Q24506.
# 	Got response for Q9VKV8.
# 	Got response for Q9VLS1.
# 	Got response for Q9VC61.
# 	Got response for Q9VFF0.
# 	Error fetching from EBI API: Cannot connect to host www.ebi.ac.uk:80 ssl:default [Connect call failed ('193.62.193.80', 80)]
# 	Got response for P40301.
# 	Got response for Q8IPY3.
# 	Got response for Q8IQM3.
# 	Got response for Q0E9E2.
# 	Got response for Q9VJC7.
# 	Got response for Q9VWV8.
# 	Got response for Q9VZV8.
# 	Got response for P46223.
# 	Got response for P15619.
# 	Got response for O77426.
# 	Got response for Q8IH79.
# 	Got response for Q9VK18.
# 	Got response for Q95083.
# 	Got response for Q9XZS3.
# 	Got response for Q9VY92.
# 	Got response for Q9VHD3.
# 	Got response for O61650.
# 	Got response for Q9VLS4.
# 	Got response for P05552.
# 	Got response for A1Z8P9.
# 	Got response for Q9W3U9.
# 	Got response for P24156.
# 	Got response for Q9VZX6.
# 	Got response for O16043.
# 	Got response for Q8IQH2.
# 	Got response for Q8IP71.
# 	Error: 404 while fetching from EBI API
# 	Got response for Q7K0D3.
# 	Got response for P35381.
# 	Got response for A1YK24.
# 	Got response for Q9XZH6.
# 	Got response for O61380.
# 	Got response for A1ZBU9.
# 	Got response for Q9V9M7.
# 	Got response for Q8IA36.
# 	Got response for O77285.
# 	Got response for A1Z8F4.
# 	Got response for Q7KSQ0.
# 	Got response for Q9V3D2.
# 	Got response for Q7K0B6.
# 	Got response for Q9W0G7.
# 	Got response for O16048.
# 	Got response for O96046.
# 	Got response for Q9I7S8.
# 	Got response for Q7K3W2.
# 	Got response for Q8SYD7.
# 	Got response for Q9VPT4.
# 	Got response for Q8SYB8.
# 	Got response for Q9VF08.
# 	Got response for Q7KSN0.
# 	Got response for Q9VXX8.
# 	Got response for Q9NHD5.
# 	Got response for Q9V4N3.
# 	Got response for Q95RW5.
# 	Got response for Q9VUB7.
# 	Got response for Q9VSE2.
# 	Got response for Q8T3H9.
# 	Got response for Q95SD3.
# 	Got response for Q7JR58.
# 	Got response for Q9W4L1.
# 	Got response for Q8MZ78.
# 	Got response for Q8IGW2.
# 	Got response for Q8T051.
# 	Got response for Q961D4.
# 	Got response for Q9V3V0.
# 	Got response for Q86BP1.
# 	Got response for Q9VS34.
# 	Got response for Q9VH39.
# 	Got response for Q9VTV4.
# 	Got response for Q8SZU4.
# 	Error: 404 while fetching from EBI API
# 	Got response for O97121.
# 	Got response for Q7K1S1.
# 	Got response for Q8IPK0.
# 	Got response for Q7K4G8.
# 	Got response for Q70HU2.
# 	Got response for O76861.
# 	Got response for Q9VK69.
# 	Error fetching from EBI API: Cannot connect to host www.ebi.ac.uk:80 ssl:default [Connect call failed ('193.62.193.80', 80)]
# 	Got response for O61231.
# 	Got response for Q95TS6.
# 	Got response for Q86PC0.
# 	Got response for Q9VND7.
# 	Error fetching from EBI API: Cannot connect to host www.ebi.ac.uk:443 ssl:default [Connect call failed ('193.62.193.80', 443)]
# 	Got response for Q9VFH4.
# 	Got response for O16040.
# 	Got response for Q9V3V9.
# 	Got response for P45437.
# 	Got response for Q8MT23.
# 	Got response for Q9VNH5.
# 	Got response for Q8IGE1.
# 	Got response for Q6NR22.
# 	Error fetching from EBI API: Cannot connect to host www.ebi.ac.uk:443 ssl:default [Connect call failed ('193.62.193.80', 443)]
# 	Got response for P20348.
# 	Got response for Q9V9U7.
# 	Got response for Q9VFQ9.
# 	Got response for Q95U38.
# 	Got response for Q01637.
# 	Got response for Q7KSU6.
# 	Got response for Q9VZ23.
# 	Got response for Q9W086.
# 	Got response for Q24466.
# 	Got response for Q8MYR4.
# 	Got response for O61345.
# 	Got response for Q9VAY7.
# 	Got response for Q7KIF8.
# 	Got response for Q9VL57.
# 	Got response for Q7K4Q9.
# 	Got response for P12982.
# 	Got response for Q8IGA2.
# 	Got response for Q7KVA9.
# 	Got response for O77410.
# 	Got response for Q9VSS1.
# 	Got response for Q5BHY9.
# 	Got response for Q94523.
# 	Got response for Q9VQG4.
# 	Got response for A1Z9L0.
# 	Got response for Q9VK59.
# 	Got response for Q27294.
# 	Got response for Q9V3C7.
# 	Got response for Q86PD3.
# 	Error fetching from EBI API: Cannot connect to host www.ebi.ac.uk:443 ssl:default [Connect call failed ('193.62.193.80', 443)]
# 	Got response for Q9VLM9.
# 	Got response for O18335.
# 	Got response for Q9VJD4.
# 	Got response for Q9W0N9.
# 	Got response for Q9VG69.
# 	Got response for Q8INT6.
# 	Got response for Q7JQY8.
# 	Got response for Q7KTV5.
# 	Got response for P14785.
# 	Got response for Q95SI7.
# 	Got response for Q8MQS7.
# 	Got response for Q7JW73.
# 	Got response for A1ZA66.
# 	Error: 404 while fetching from EBI API
# 	Got response for Q8IN24.
# 	Got response for Q94522.
# 	Got response for Q9VLC5.
# 	Error fetching from EBI API: Cannot connect to host www.ebi.ac.uk:80 ssl:default [Connect call failed ('193.62.193.80', 80)]
# 	Got response for Q9VAY2.
# 	Got response for Q8MRU8.
# 	Got response for Q7K0E6.
# 	Got response for Q9VT75.
# 	Got response for Q9GU68.
# 	Got response for P53034.
# 	Got response for P46415.
# 	Got response for Q9VKV4.
# 	Got response for Q27580.
# 	Got response for Q8MSY0.
# 	Got response for O17445.
# 	Got response for A1Z6M0.
# 	Error fetching from EBI API: Cannot connect to host www.ebi.ac.uk:443 ssl:default [Connect call failed ('193.62.193.80', 443)]
# 	Got response for Q7KA77.
# 	Got response for Q8SZ19.
# 	Got response for Q9VGV9.
# 	Got response for Q494G8.
# 	Got response for Q8T3P8.
# 	Got response for Q9VP51.
# 	Got response for Q95TH0.
# 	Got response for P29742.
# 	Got response for Q9VWQ3.
# 	Got response for Q95TZ9.
# 	Got response for Q9V3L6.
# 	Got response for P08736.
# 	Got response for Q7YZ93.
# 	Got response for Q9VP50.
# 	Got response for Q95RR1.
# 	Got response for P41900.
# 	Got response for Q9VFC0.
# 	Got response for Q9W1Y0.
# 	Error: 404 while fetching from EBI API
# 	Got response for
# 	Got response for Q9VLN1.
# 	Got response for Q7JX41.
# 	Got response for Q8IGW8.
# 	Got response for Q9VDT1.
# 	Got response for Q9VQ58.
# 	Got response for Q9VE01.
# 	Got response for Q9VJ44.
# 	Got response for Q9VYV4.
# 	Got response for O97428.
# 	Got response for Q9VZE4.
# 	Got response for Q24147.
# 	Got response for A1Z784.
# 	Got response for A1Z934.
# 	Got response for Q9VCA9.
# 	Got response for P84029.
# 	Got response for Q8IPU3.
# 	Got response for Q7KTK9.
# 	Got response for P50882.
# 	Got response for Q9W2U6.
# 	Got response for Q9VMX3.
# 	Got response for Q9I7U7.
# 	Got response for Q9VVU2.
# 	Got response for Q0E8J0.
# 	Got response for Q95RJ9.
# 	Got response for Q8T3U2.
# 	Error fetching from EBI API: Cannot connect to host www.ebi.ac.uk:443 ssl:default [Connect call failed ('193.62.193.80', 443)]
# 	Got response for O18406.
# 	Got response for Q9VX38.
# 	Got response for O18404.
# 	Got response for A4V310.
# 	Got response for P56538.
# 	Got response for Q95NR4.
# 	Got response for Q5U183.
# 	Got response for Q9VRG6.
# 	Got response for Q9VYV3.
# 	Got response for Q8IPC6.
# 	Error: 404 while fetching from EBI API
# 	Got response for Q9VMU4.
# 	Got response for Q9VFV9.
# 	Got response for Q95RC6.
# 	Got response for Q9VZZ6.
# 	Got response for P50887.
# 	Got response for Q9VHE5.
# 	Got response for Q9V3K3.
# 	Got response for Q9VVU5.
# 	Got response for A1ZAK3.
# 	Got response for Q9VMU0.
# 	Got response for Q9V3B6.
# 	Got response for Q9VQB6.
# 	Got response for Q9XZ63.
# 	Got response for Q9XZ61.
# 	Got response for Q7K206.
# 	Got response for P48609.
# 	Got response for Q7KV27.
# 	Got response for Q9XTP7.
# 	Got response for Q9VW56.
# 	Got response for Q9VW59.
# 	Got response for Q961F0.
# 	Got response for Q2XY62.
# 	Got response for Q7KJV5.
# 	Got response for P25867.
# 	Got response for Q9VQ40.
# 	Got response for Q8IMK5.
# 	Got response for Q7K1H5.
# 	Got response for Q94920.
# 	Got response for Q9VGU7.
# 	Got response for Q9VNI8.
# 	Got response for Q9VV60.
# 	Got response for Q9VI23.
# 	Got response for Q9VJ33.
# 	Got response for Q95TL8.
# 	Got response for Q9VJZ6.
# 	Got response for Q8IH24.
# 	Got response for Q7KJ37.
# 	Got response for Q9VG81.
# 	Got response for Q9VL68.
# 	Got response for Q9VJZ5.
# 	Got response for P91928.
# 	Got response for Q8SZE4.
# 	Got response for Q95TR0.
# 	Got response for Q7KK96.
# 	Got response for Q9VWI1.
# 	Got response for Q9VGQ1.
# 	Got response for Q9VRZ7.
# 	Got response for Q9VU88.
# 	Got response for Q8SXQ5.
# 	Got response for Q9VXM4.
# 	Got response for Q1KN24.
# 	Got response for Q9V405.
# 	Got response for Q7KTT0.
# 	Got response for Q9VYD5.
# 	Got response for Q9W334.
# 	Got response for Q9GS19.
# 	Got response for Q9VF24.
# 	Got response for Q07886.
# 	Error fetching from EBI API: Cannot connect to host www.ebi.ac.uk:443 ssl:default [Connect call failed ('193.62.193.80', 443)]
# 	Got response for
# 	Got response for Q5VV52.
# 	Got response for O32293.
# 	Got response for Q8TCN5.
# 	Got response for Q15326.
# 	Got response for Q3SXZ3.
# 	Got response for P54169.
# 	Got response for Q9Y2D9.
# 	Got response for Q9Y5V0.
# 	Got response for P08048.
# 	Got response for Q8WTR7.
# 	Got response for P0CG31.
# 	Got response for Q795M6.
# 	Got response for P47043.
# 	Got response for Q9H8U3.
# 	Got response for Q9Y6M5.
# 	Got response for Q8N3Z6.
# 	Got response for P17022.
# 	Got response for A0A0G2K2P5.
# 	Got response for Q795Q5.
# 	Got response for Q12512.
# 	Got response for O75312.
# 	Got response for Q96BR6.
# 	Got response for Q9QZ48.
# 	Got response for O05240.
# 	Got response for Q2TB10.
# 	Got response for Q9UGR2.
# 	Got response for P53735.
# 	Got response for P40021.
# 	Got response for Q9UDV7.
# 	Got response for P20107.
# 	Got response for P32804.
# 	Got response for Q62384.
# 	Got response for O43829.
# 	Got response for Q96MP5.
# 	Got response for Q9Y2K1.
# 	Got response for Q9P2E3.
# 	Got response for O54767.
# 	Got response for Q9H707.
# 	Got response for Q16670.
# 	Got response for Q9UDY2.
# 	Got response for Q86W11.
# 	Got response for P12688.
# 	Got response for Q8TBF4.
# 	Got response for Q9BS86.
# 	Got response for Q5T200.
# 	Got response for Q9H6R6.
# 	Got response for Q9NPA5.
# 	Error: 404 while fetching from EBI API
# 	Got response for Q9HCJ5.
# 	Got response for P94521.
# 	Got response for O32075.
# 	Got response for P96720.
# 	Got response for P17098.
# 	Got response for Q86YA3.
# 	Got response for P37502.
# 	Got response for Q9DB43.
# 	Got response for P0CJ79.
# 	Got response for Q96CK0.
# 	Got response for P17028.
# 	Got response for P53303.
# DONE FOR Acetylation

# %%
import psutil

# %%
import requests

def fetch_sequence_thread(accession_number: str) -> tuple[str, bool, str]:
    real_acc = accession_number
    got_response = True
    got_sequence = True
    sequence = ''
    
    while got_response:
        try:
            got_response = False
            response = requests.get(f'http://www.ebi.ac.uk/proteins/api/proteins/{accession_number}')
            print(f"\tGot response for {accession_number}.")
            if response.status_code == 200:
                data = response.json()
                sequence = data['sequence']['sequence']
                got_sequence = True
            else:
                got_sequence = False
                print(f"\tError: {response.status_code} while fetching from EBI API")
        except Exception as e:
            print(f"\tError fetching from EBI API: {e}")
            got_response = True

    if not got_sequence:  # If sequence wasn't found in the first API, try the second one
        while got_response:
            try:
                got_response = False
                response = requests.get(
                    f'https://rest.uniprot.org/uniprotkb/{accession_number}',
                    headers={'Accept': 'application/json'}
                )
                print(f"\tGot response for {accession_number} from UniProt.")
                if response.status_code == 200:
                    data = response.json()
                    if 'inactiveReason' in data:
                        if data['inactiveReason']['inactiveReasonType'] == 'DELETED':
                            print("\tWas deleted")
                            uniparc_id = data['extraAttributes']['uniParcId']
                            # Try fetching UniParc data
                            uniparc_response = requests.get(
                                f'https://rest.uniprot.org/uniparc/{uniparc_id}',
                                headers={'Accept': 'application/json'}
                            )
                            if uniparc_response.status_code == 200:
                                uniparc_data = uniparc_response.json()
                                sequence = uniparc_data['sequence']['value']
                                got_sequence = True
                        elif data['inactiveReason']['inactiveReasonType'] == 'DEMERGED':
                            print("\tWas merged")
                            accession_number = data['inactiveReason']['mergeDemergeTo'][0]
                            got_response = True
                            continue  # If merged, retry with new accession number
                    else:
                        sequence = data['sequence']['value']
                        got_sequence = True
                else:
                    print(f"\tError: {response.status_code} while fetching from UniProt")
            except Exception as e:
                print(f"\tError fetching from UniProt API: {e}")
                got_response = True

    return real_acc, got_sequence, sequence

# For running the synchronous operation serially
def run_serially():
    files = ['ADP-ribosylation'] # list(get_files().keys())
    for file in files:
        print("DOING FOR", file)
        df = pd.read_csv(
            'rawDataset2025/' + file,
            names=[
                'ProID',
                'Acc#',
                'ModSite',
                'PTM',
                'EvdId',
                'Seq'
            ],
            header=None,
            sep='\t'
        )
        df['FullSeq'] = ''
        for acc in df['Acc#'].unique():
            acc, got_sequence, sequence = fetch_sequence_thread(acc)
            df.loc[df['Acc#'] == acc, 'FullSeq'] = sequence
        df.to_csv('rawDataset2025/' + file + '_full.csv', index=False)
        print("DONE FOR", file)

# %%
run_serially()
# Out:
# DOING FOR ADP-ribosylation
# 	Got response for P61247.
# 	Got response for Q9NWY4.
# 	Got response for O00479.
# 	Got response for P05114.
# 	Got response for P05204.
# 	Got response for P06748.
# 	Got response for P07305.
# 	Got response for P09429.
# 	Got response for P09874.
# 	Got response for P10412.
# 	Got response for P16403.
# 	Got response for P17096.
# 	Got response for P35659.
# 	Got response for P58876.
# 	Got response for P61224.
# 	Got response for P68431.
# 	Got response for P84243.
# 	Got response for Q00839.
# 	Got response for Q71DI3.
# 	Got response for Q96EY4.
# 	Got response for Q99879.
# 	Got response for Q99880.
# 	Got response for Q9Y2S6.
# 	Got response for P0A7Z4.
# 	Got response for P0A850.
# 	Got response for P0A9A6.
# 	Got response for P0AE70.
# 	Got response for P20974.
# 	Got response for P22921.
# 	Got response for P43220.
# 	Got response for P48675.
# 	Got response for P59665.
# 	Got response for P68135.
# 	Got response for Q03250.
# 	Got response for Q8RXG3.
# 	Got response for Q9Z1M0.
# 	Got response for P61585.
# 	Got response for P61586.
# 	Got response for O88554.
# 	Got response for Q53GL7.
# 	Got response for Q8N5Y8.
# 	Got response for Q9NR21.
# 	Got response for Q9Y6F1.
# 	Got response for P09445.
# 	Got response for P13639.
# 	Got response for P0CG47.
# 	Got response for P0CG48.
# 	Got response for P62979.
# 	Got response for P62987.
# 	Got response for P42224.
# 	Got response for Q6B0I6.
# 	Got response for P0DN69.
# 	Got response for Q2NL67.
# 	Got response for Q9H0J9.
# 	Got response for P00367.
# 	Got response for P04797.
# 	Got response for P49448.
# 	Got response for Q7Z3E1.
# 	Got response for Q8N3A8.
# DONE FOR ADP-ribosylation

# %%
df_serial = pd.read_csv('rawDataset2025/ADP-ribosylation_full_serial.csv')
df_parallel = pd.read_csv('rawDataset2025/ADP-ribosylation_full_parallel.csv')

# %%
df_serial.equals(df_parallel)
# Out:
# True
